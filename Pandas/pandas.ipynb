# %%
import pandas as pd

# %%
info = {
    "name" : ["sravan kumar", "sandeep", "sathish"],
    "CGPA" : [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)

print(df)
# Out:
#            name  CGPA
# 0  sravan kumar   9.5
# 1       sandeep   7.5
# 2       sathish   8.5

# %%
#series(1D labelled array)
s = pd.Series([1,2,3,4,5])
print(s, s.dtype)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64 int64
