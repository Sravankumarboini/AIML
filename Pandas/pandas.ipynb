# %%
import pandas as pd

# %%
info = {
    "name" : ["sravan kumar", "sandeep", "sathish"],
    "CGPA" : [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)

print(df)
# Out:
#            name  CGPA
# 0  sravan kumar   9.5
# 1       sandeep   7.5
# 2       sathish   8.5

# %%
#series(1D labelled array)
s = pd.Series([1,2,3,4,5])
print(s, type(s))

#index
print(s[0])
print(s[1])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64 <class 'pandas.core.series.Series'>
# 1
# 2

# %%
s = pd.Series([23,34,24,54], index=["adam", "eve", "mikasa", "hinata"])
print(s)
# Out:
# adam      23
# eve       34
# mikasa    24
# hinata    54
# dtype: int64
