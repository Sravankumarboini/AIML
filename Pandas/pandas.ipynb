# %%
import pandas as od

# %%
info = {
    "name" : ["sravan kumar", "sandeep", "sathish"],
    "CGPA" : [9.5, 7.5, 8.5]
}

df = pd.DataFrame(info)

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 info = {
#       2     "name" : ["sravan kumar", "sandeep", "sathish"],
#       3     "CGPA" : [9.5, 7.5, 8.5]
#       4 }
# ----> 6 df = pd.DataFrame(info)
#       8 print(df)
#
# NameError: name 'pd' is not defined
