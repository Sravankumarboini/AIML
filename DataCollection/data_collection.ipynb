# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
URL = "https://potterapi-fedeperin.vercel.app/en/books"

res = requests.get(URL)

# %%
json_data = res.json()

# %%
import pandas as pd 

df = pd.json_normalize(json_data)
df = df[['number', 'title', 'releaseDate', 'pages']]

# %%
df
# Out:
#    number                                      title   releaseDate  pages
# 0       1      Harry Potter and the Sorcerer's Stone  Jun 26, 1997    223
# 1       2    Harry Potter and the Chamber of Secrets   Jul 2, 1998    251
# 2       3   Harry Potter and the Prisoner of Azkaban   Jul 8, 1999    317
# 3       4        Harry Potter and the Goblet of Fire   Jul 8, 2000    636
# 4       5  Harry Potter and the Order of the Phoenix  Jun 21, 2003    766
# 5       6     Harry Potter and the Half-Blood Prince  Jul 16, 2005    607
# 6       7       Harry Potter and the Deathly Hallows  Jul 21, 2007    607
# 7       8          Harry Potter and the Cursed Child  Jul 30, 2016    336

# %%
URL = "https://dattebayo-api.onrender.com/characters"

res = requests.get(URL)

res
# Out:
# <Response [200]>

# %%
json_data = res.json()

# %%
import pandas as pd

df = pd.json_normalize(json_data["characters"])

df = df[['id', 'name', 'jutsu', 'natureType']]

# %%
df
# Out:
#       id                 name  \
# 0   1344       Naruto Uzumaki
# 1   1307        Sasuke Uchiha
# 2   1299        Madara Uchiha
# 3    376       Kakashi Hatake
# 4    928           Orochimaru
# 5   1303         Obito Uchiha
# 6    259                Gaara
# 7   1359       Kabuto Yakushi
# 8    515              Jiraiya
# 9   1373               Yamato
# 10   344            Might Guy
# 11  1037  Konohamaru Sarutobi
# 12   813              Mitsuki
# 13   865      Minato Namikaze
# 14  1339       Boruto Uzumaki
# 15  1293        Itachi Uchiha
# 16  1063      Hashirama Senju
# 17  1280              Tsunade
# 18   739             Rock Lee
# 19   600          Koji Kashin
#
#                                                 jutsu  \
# 0   [All Directions Shuriken, Baryon Mode, Big Bal...
# 1   [Afterglow, Amaterasu, Amaterasu: Flame Wrappi...
# 2   [Animal Path, Asura Path, Black Receiver, Bloc...
# 3   [Area Scanning Technique, Chidori, Demonic Ill...
# ...

# %%
#WEB SCRAPING
